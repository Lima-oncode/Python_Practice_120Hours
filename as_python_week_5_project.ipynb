# %%
import pandas as pd

# %% [markdown]
# Lendo o Data Frame

# %%
data = pd.read_csv("openbeerdb_csv/beers.csv", low_memory=False, usecols=["name", "abv"], nrows=100)

# %% [markdown]
# Métodos disponíveis para o notebook

# %%
dir(data)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
# ...

# %% [markdown]
# Visualizando os dados do Data Frame

# %%
data
# Out:
#                       name  abv
# 0              Hocus Pocus  4.5
# 1        Grimbergen Blonde  6.7
# 2   Widdershins Barleywine  9.1
# 3                  Lucifer  8.5
# 4                   Bitter  4.0
# ..                     ...  ...
# 95  Brunette Nut Brown Ale  0.0
# 96               Irish Red  0.0
# 97             Belgian Wit  0.0
# 98          EOS Hefeweizen  0.0
# 99          India Pale Ale  0.0
#
# [100 rows x 2 columns]

# %% [markdown]
# Tipando uma colunas específica do dataframe

# %%
data["abv"] = data["abv"].astype(float)

# %% [markdown]
# Gerando um gráfico com matplotlib com base nos dados do dataframe

# %%
data.plot(kind="barh", x='name', y='abv', figsize=(20, 20))
# Out:
# <Axes: ylabel='name'>

# %% [markdown]
# # Usando Pandas para WebScrapping

# %%
dfscrap = pd.read_html("https://pt.wikipedia.org/wiki/Lista_de_pa%C3%ADses_por_consumo_de_%C3%A1lcool", attrs={"class":"wikitable"})
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dfscrap = pd.read_html("https://pt.wikipedia.org/wiki/Lista_de_pa%C3%ADses_por_consumo_de_%C3%A1lcool", attrs={"class":"wikitable"})
#
# File ~\.virtualenvs\Aulas_curso_em_video-wyKyerGZ\Lib\site-packages\pandas\io\html.py:1212, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend)
#    1208 check_dtype_backend(dtype_backend)
#    1210 io = stringify_path(io)
# -> 1212 return _parse(
#    1213     flavor=flavor,
#    1214     io=io,
#    1215     match=match,
#    1216     header=header,
#    1217     index_col=index_col,
#    1218     skiprows=skiprows,
#    1219     parse_dates=parse_dates,
#    1220     thousands=thousands,
#    1221     attrs=attrs,
# ...

# %%
dfscrap
# Out:
# [   Legenda                                          Legenda.1
#  0      NaN  A equipe também venceu o Campeonato de Constru...,
#      Campeonatos              Piloto                    Temporadas
#  0             5  Michael Schumacher  2000, 2001, 2002, 2003, 2004
#  1             4  Juan Manuel Fangio        1954, 1955, 1956, 1957
#  2             4    Sebastian Vettel        2010, 2011, 2012, 2013
#  3             4      Lewis Hamilton        2017, 2018, 2019, 2020
#  4             2      Alberto Ascari                    1952, 1953
#  5             2        Jack Brabham                    1959, 1960
#  6             2         Alain Prost                    1985, 1986
#  7             2        Ayrton Senna                    1990, 1991
#  8             2  Michael Schumacher                    1994, 1995
#  9             2       Mika Häkkinen                    1998, 1999
#  10            2     Fernando Alonso                    2005, 2006
# ...
